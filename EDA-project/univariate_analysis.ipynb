# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import *

# %%
# Load the data
file_path = 'processed_EDA_Loan.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the data
print("First few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
#    ...  Credit Score No. of Defaults Has Active Credit Card  Property ID  \
# 0  ...        809.44             0.0                    NaN          746
# 1  ...        780.40             0.0            Unpossessed          608
# 2  ...        833.15             0.0            Unpossessed          546
# 3  ...        832.70             0.0            Unpossessed          890
# 4  ...        745.55             0.0                 Active          715
#
#    Property Age  Property Type Property Location  Co-Applicant  \
# 0       1933.05              4             Rural           1.0
# 1       4952.91              2             Rural           1.0
# 2        988.19              2             Urban           1.0
# 3           NaN              2        Semi-Urban           1.0
# 4       2614.77              4        Semi-Urban           1.0
#
#    Property Price  Loan Sanction Amount (USD)
# 0       119933.46                    54607.18
# 1        54791.00                    37469.98
# 2        72440.58                    36474.43
# 3       121441.51                    56040.54
# 4       208567.91                    74008.28
#
# [5 rows x 24 columns]

# %%
# Univariate Analysis for Numerical Features

numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

print("\nSummary Statistics for Numerical Features:")
for column in numerical_columns:
    print(f"\nStatistics for {column}:")
    print(f"Mean: {data[column].mean()}")
    print(f"Median: {data[column].median()}")

    # Measures of Dispersion
    print(f"Range: {data[column].max() - data[column].min()}")
    print(f"Variance: {data[column].var()}")
    print(f"Standard Deviation: {data[column].std()}")

    # Measures of Shape
    print(f"Skewness: {data[column].skew()}")
    print(f"Kurtosis: {data[column].kurtosis()}")

    # Histogram
    plt.figure(figsize=(10, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Summary Statistics for Numerical Features:
#
# Statistics for Age:
# Mean: 40.0923
# Median: 40.0
# Range: 47
# Variance: 257.44616224874164
# Standard Deviation: 16.04512892589965
# Skewness: 0.046093801598670575
# Kurtosis: -1.3820829377043198
# Statistics for Income (USD):
# Mean: 2339.2525519194464
# Median: 2222.4175
# Range: 4871.56
# Variance: 900033.7449260957
# Standard Deviation: 948.7010830214624
# Skewness: 0.7498916371880613
# Kurtosis: 0.1868152872095914
# Statistics for Loan Amount Request (USD):
# Mean: 83731.14974133333
# Median: 75127.8075
# Range: 232085.78
# Variance: 2581832966.0470986
# Standard Deviation: 50811.74043513073
# Skewness: 0.8144025243752381
# Kurtosis: -0.015860832814377446
# Statistics for Current Loan Expenses (USD):
# Mean: 392.1016241450986
# Median: 375.205
# Range: 897.89
# Variance: 33601.15964767303
# Standard Deviation: 183.30619096929877
# Skewness: 0.563667371110584
# Kurtosis: -0.18882669384516504
# Statistics for Dependents:
# Mean: 2.2029665176136985
# Median: 2.0
# Range: 3.0
# Variance: 0.7615006882921079
# Standard Deviation: 0.872640068007485
# Skewness: 0.48274705087607656
# Kurtosis: -0.357794725246277
# Statistics for Credit Score:
# Mean: 739.8853811358094
# Median: 739.82
# Range: 316.26
# Variance: 5207.620683584763
# Standard Deviation: 72.1638460975076
# Skewness: -0.020255169213215216
# Kurtosis: -0.9851944798802634
# Statistics for No. of Defaults:
# Mean: 0.0
# Median: 0.0
# Range: 0.0
# Variance: 0.0
# Standard Deviation: 0.0
# Skewness: 0.0
# Kurtosis: 0.0
# Statistics for Property ID:
# Mean: 501.9347
# Median: 504.0
# Range: 998
# Variance: 83035.08240532351
# Standard Deviation: 288.15808578855376
# Skewness: -0.010519189724274059
# Kurtosis: -1.2025636611134496
# Statistics for Property Age:
# Mean: 2340.4029928429427
# Median: 2223.225
# Range: 4874.51
# Variance: 901483.4117088882
# Standard Deviation: 949.4648027751678
# Skewness: 0.7491679077272163
# Kurtosis: 0.18283970562124896
# Statistics for Property Type:
# Mean: 2.4600666666666666
# Median: 2.0
# Range: 3
# Variance: 1.2511803682344966
# Standard Deviation: 1.1185617409130784
# Skewness: 0.051070209039890846
# Kurtosis: -1.3590012645418166
# Statistics for Co-Applicant:
# Mean: 1.0
# Median: 1.0
# Range: 0.0
# Variance: 0.0
# Standard Deviation: 0.0
# Skewness: 0.0
# Kurtosis: 0.0
# Statistics for Property Price:
# Mean: 122574.687298
# Median: 109992.1
# Range: 357195.43
# Variance: 5966081359.474358
# Standard Deviation: 77240.41273500782
# Skewness: 0.8300184734536873
# Kurtosis: 0.07185863533642811
# Statistics for Loan Sanction Amount (USD):
# Mean: 44972.5414919083
# Median: 35209.1275
# Range: 186545.3
# Variance: 1885932645.6307602
# Standard Deviation: 43427.32602441417
# Skewness: 0.9028444197476146
# Kurtosis: 0.12185047940410554
